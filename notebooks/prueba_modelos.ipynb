# %%
import sys

sys.path.insert(0, "../src")

from models import (
    cargar_indice,
    BuscadorJaccard,
    BuscadorCoseno,
    BuscadorBM25,
    mostrar_resultados,
)
import pandas as pd

df = pd.read_csv("../data/processed/corpus_limpio.csv")
datos = cargar_indice()
jac = BuscadorJaccard(datos_indice=datos)
cos = BuscadorCoseno(datos_indice=datos)
bm25 = BuscadorBM25(datos_indice=datos)
# Out:
# Cargando índice desde C:\Users\Acer123\OneDrive - Escuela Politécnica Nacional\7MO\IR\motor_busqueda_RI\data\processed\indice_invertido.pkl...
# Índice listo: 57,057 términos | 74,517 documentos.
# Precomputando normas TF-IDF de los documentos...
# Normas listas.

# %%
from rich.console import Console
from rich.table import Table
from rich import box

console = Console()


def mostrar_tabla(resultados, modelo, consulta, corpus_df=None):
    tabla = Table(
        title=f'🔍  "{consulta}"',
        box=box.DOUBLE_EDGE,
        show_header=True,
        header_style="bold cyan",
    )
    tabla.add_column("#", style="dim", width=4, justify="right")
    tabla.add_column("Título", width=45)
    tabla.add_column("Score", style="green", width=10, justify="right")
    tabla.caption = f"Modelo: {modelo}  |  {len(resultados)} resultado(s)"

    for i, (doc_id, score) in enumerate(resultados, 1):
        titulo = doc_id[:43] + "..."
        if corpus_df is not None:
            fila = corpus_df[corpus_df["job_id"] == doc_id]
            if not fila.empty:
                titulo = fila.iloc[0]["job_title"]
        tabla.add_row(str(i), titulo, f"{score:.4f}")

    console.print(tabla)

# %%
consulta = "analista de datos python"

mostrar_tabla(jac.buscar(consulta, top_k=10), "Jaccard", consulta, df)
mostrar_tabla(cos.buscar(consulta, top_k=10), "Coseno TF-IDF", consulta, df)
mostrar_tabla(bm25.buscar(consulta, top_k=10), "BM25", consulta, df)
# Out:
#                    🔍  "analista de datos python"
# ╔══════╤═══════════════════════════════════════════════╤════════════╗
# ║    # │ Título                                        │      Score ║
# ╟──────┼───────────────────────────────────────────────┼────────────╢
# ║    1 │ staff data analyst                            │     0.1333 ║
# ║    2 │ data scientist fort meade                     │     0.1111 ║
# ║    3 │ data analyst python programming work from     │     0.1071 ║
# ║      │ home                                          │            ║
# ║    4 │ data analyst                                  │     0.1000 ║
# ║    5 │ lider de produccion                           │     0.1000 ║
# ║    6 │ data analyst w2 only                          │     0.1000 ║
# ║    7 │ analista pleno netbackup e tsm hibrido sp     │     0.0968 ║
# ║    8 │ alternant data steward data analyst           │     0.0952 ║
# ║    9 │ data engineer enterprise data warehouse       │     0.0952 ║
# ║   10 │ data scientist                                │     0.0909 ║
# ╚══════╧═══════════════════════════════════════════════╧════════════╝
#                  Modelo: Jaccard  |  10 resultado(s)
#                    🔍  "analista de datos python"
# ╔══════╤═══════════════════════════════════════════════╤════════════╗
# ║    # │ Título                                        │      Score ║
# ╟──────┼───────────────────────────────────────────────┼────────────╢
# ║    1 │ data analyst python programming work from     │     0.5616 ║
# ║      │ home                                          │            ║
# ║    2 │ data analyst                                  │     0.4364 ║
# ║    3 │ job opportunity data analyst                  │     0.4232 ║
# ║    4 │ lead data analyst                             │     0.4122 ║
# ║    5 │ data analyst                                  │     0.4028 ║
# ║    6 │ data analyst                                  │     0.3984 ║
# ║    7 │ senior clinical data analyst                  │     0.3926 ║
# ║    8 │ data analyst                                  │     0.3899 ║
# ║    9 │ senior data analyst                           │     0.3795 ║
# ║   10 │ data analyst                                  │     0.3740 ║
# ╚══════╧═══════════════════════════════════════════════╧════════════╝
#               Modelo: Coseno TF-IDF  |  10 resultado(s)
#                    🔍  "analista de datos python"
# ╔══════╤═══════════════════════════════════════════════╤════════════╗
# ║    # │ Título                                        │      Score ║
# ╟──────┼───────────────────────────────────────────────┼────────────╢
# ║    1 │ analista pleno netbackup e tsm hibrido sp     │    15.9268 ║
# ║    2 │ data analyst python programming work from     │    15.9192 ║
# ║      │ home                                          │            ║
# ║    3 │ analista pleno de ia generativa               │    14.6369 ║
# ║    4 │ analista de datos                             │    14.3228 ║
# ║    5 │ analista de desenvolvimento de software pleno │    14.1803 ║
# ║    6 │ master data specialist                        │    13.8827 ║
# ║    7 │ data analyst w2 only                          │    13.4768 ║
# ║    8 │ data scientist fort meade                     │    13.4220 ║
# ║    9 │ senior quantitative researcher buy side phd   │    12.6527 ║
# ║      │ preferred                                     │            ║
# ║   10 │ sr data analyst richmond va onsite hybrid     │    12.5012 ║
# ║      │ richmond va                                   │            ║
# ╚══════╧═══════════════════════════════════════════════╧════════════╝
#                   Modelo: BM25  |  10 resultado(s)
